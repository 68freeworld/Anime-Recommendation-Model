# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# # New Section

# %%
with open('anime_df_clean.pkl', 'rb') as f:
    anime_df_clean = pickle.load(f)

with open('rating_df_clean.pkl', 'rb') as f:
    rating_df_clean = pickle.load(f)

# %%
anime_df_clean
# Out:
#                                            anime_name  anime_id  \
# 0                                        Cowboy Bebop         1
# 1                     Cowboy Bebop: Tengoku no Tobira         5
# 2                                              Trigun         6
# 3                                  Witch Hunter Robin         7
# 4                                      Bouken Ou Beet         8
# ...                                               ...       ...
# 12401                   Kimetsu Gakuen: Valentine-hen     47398
# 12402                                       Heikousen     47402
# 12403    Nu Wushen de Canzhuo Spring Festival Special     47614
# 12404  Yakusoku no Neverland 2nd Season: Michishirube     47616
# 12405                             SK∞: Crazy Rock Jam     48456
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 12401                                             Comedy
# 12402                                     Music, Romance
# 12403                              Slice of Life, Comedy
# 12404  Mystery, Psychological, Supernatural, Thriller...
# 12405                                     Comedy, Sports
#
#                                                 Synopsis  Score
# 0      In the year 2071, humanity has colonized sever...   8.78
# 1      other day, another bounty—such is the life of ...   8.39
# 2      Vash the Stampede is the man with a $$60,000,0...   8.24
# 3      ches are individuals with special powers like ...   7.27
# 4      It is the dark century and the people are suff...   6.98
# ...                                                  ...    ...
# 12401  Valentine's Day special for Kimetsu no Yaiba ....   6.59
# 12402  usic video for Eve and suis' song Heikousen , ...   7.52
# 12403  No synopsis information has been added to this...   6.83
# 12404  cap of the first season of Yakusoku no Neverla...   4.81
# 12405               cap of the first 9 episodes of SK∞ .   6.52
#
# [12406 rows x 5 columns]

# %%
rating_df_clean
# Out:
#           user_id  anime_id  rating  \
# 0               0       430       9
# 1               0      1004       5
# 2               0      3010       7
# 3               0       570       7
# 4               0      2762       9
# ...           ...       ...     ...
# 57633273   353404       502       8
# 57633274   353404       987       4
# 57633275   353404       225       8
# 57633276   353404       243       7
# 57633277   353404       896       7
#
#                                                  anime_name
# 0           Fullmetal Alchemist: The Conqueror of Shamballa
# 1                                  Kanojo to Kanojo no Neko
# 2                                            Kaiketsu Zorro
# 3                                                   Jin-Rou
# 4                                            Igano Kabamaru
# ...                                                     ...
# 57633273         Dragon Ball Movie 1: Shen Long no Densetsu
# 57633274  Dragon Ball GT: Gokuu Gaiden! Yuuki no Akashi ...
# 57633275                                     Dragon Ball GT
# 57633276                                        Gravitation
# 57633277  Dragon Ball Z Movie 03: Chikyuu Marugoto Chouk...
#
# [57633278 rows x 4 columns]

# %%
print(rating_df_clean.dtypes)
# Out:
# user_id        int64
# anime_id       int64
# rating         int64
# anime_name    object
# dtype: object

# %%
print("\n### Recommendations Based on Popularity (Most Rated) ###")

# Count how many times each anime appears in the ratings dataframe
anime_popularity = rating_df_clean['anime_name'].value_counts()

# Get the top 10 most frequently rated anime
top_10_popular_anime = anime_popularity.head(10)

print("Top 10 Most Popular Anime (by number of ratings):")
print(top_10_popular_anime)
print("-" * 30)
# Out:
# ### Recommendations Based on Popularity (Most Rated) ###
# Top 10 Most Popular Anime (by number of ratings):
# anime_name
# Death Note                          182375
# Shingeki no Kyojin                  169794
# Sword Art Online                    161192
# Angel Beats!                        141127
# One Punch Man                       138924
# Code Geass: Hangyaku no Lelouch     137291
# Toradora!                           135524
# Fullmetal Alchemist: Brotherhood    134197
# No Game No Life                     129009
# Tokyo Ghoul                         128822
# Name: count, dtype: int64
# ------------------------------

# %%
print("\n### Recommendations Based on Average Rating (Simple) ###")

# Calculate the average rating for each anime
# Group by anime_name and calculate the mean of the 'rating' column
avg_rating_df = rating_df_clean.groupby('anime_name')['rating'].mean()

# Sort the results by average rating in descending order
sorted_avg_rating_df = avg_rating_df.sort_values(ascending=False)

print("Top 10 Highest Rated Anime (Simple Average):")
print(sorted_avg_rating_df.head(10))
print("-" * 30)
# Out:
# ### Recommendations Based on Average Rating (Simple) ###
# Top 10 Highest Rated Anime (Simple Average):
# anime_name
# Momotarou no Koutsuu Anzen Kyoushitsu                                                       10.000000
# Tatoeba Last Dungeon Mae no Mura no Shounen ga Joban no Machi de Kurasu Youna Monogatari    10.000000
# Osakini Douzo Arigatou                                                                      10.000000
# Ni wa no Kotori                                                                             10.000000
# Nendjuugyouji Animation Series                                                              10.000000
# Onita no Boushi                                                                             10.000000
# Oz no Mahoutsukai no Koutsuu Anzen no Tabi                                                   9.333333
# Gintama°                                                                                     9.245648
# Fullmetal Alchemist: Brotherhood                                                             9.237010
# Ginga Eiyuu Densetsu                                                                         9.224730
# Name: rating, dtype: float64
# ------------------------------

# %%
print("Checking number of ratings for the top simple average rated anime:")
top_avg_rated_names = sorted_avg_rating_df.head(10).index
ratings_count_for_top_avg = rating_df_clean[rating_df_clean['anime_name'].isin(top_avg_rated_names)]['anime_name'].value_counts()
print(ratings_count_for_top_avg)
print("(Notice: Some might have very few ratings, making the high average less reliable)")
print("-" * 30)
# Out:
# Checking number of ratings for the top simple average rated anime:
# anime_name
# Fullmetal Alchemist: Brotherhood                                                            134197
# Gintama°                                                                                     20794
# Ginga Eiyuu Densetsu                                                                          9438
# Oz no Mahoutsukai no Koutsuu Anzen no Tabi                                                       3
# Ni wa no Kotori                                                                                  2
# Nendjuugyouji Animation Series                                                                   1
# Osakini Douzo Arigatou                                                                           1
# Onita no Boushi                                                                                  1
# Momotarou no Koutsuu Anzen Kyoushitsu                                                            1
# Tatoeba Last Dungeon Mae no Mura no Shounen ga Joban no Machi de Kurasu Youna Monogatari         1
# Name: count, dtype: int64
# (Notice: Some might have very few ratings, making the high average less reliable)
# ------------------------------

# %%
print("\n### Recommendations Based Popularity-Driven Average Rating ###")

#  calculate average ratings and counts for all anime
anime_stats = rating_df_clean.groupby('anime_name').agg(
    Avg_Rating=('rating', 'mean'),
    Num_Ratings=('rating', 'count')
).reset_index()


# Calculate the mean or median number of ratings to get a sense of distribution
mean_ratings = anime_stats['Num_Ratings'].mean()
median_ratings = anime_stats['Num_Ratings'].median()
print(f"Mean number of ratings per anime: {mean_ratings:.2f}")
print(f"Median number of ratings per anime: {median_ratings:.2f}")

.
threshold = 200
print(f"Using a minimum rating threshold of: {threshold}")

# Filter the stats DataFrame to include only anime with enough ratings
frequent_anime_stats = anime_stats[anime_stats['Num_Ratings'] >= threshold]

# Sort these frequently rated anime by their average rating
frequent_anime_sorted = frequent_anime_stats.sort_values(by='Avg_Rating', ascending=False)

print(f"\nTop 10 Highest Rated Anime (with at least {threshold} ratings):")
print(frequent_anime_sorted[['anime_name', 'Avg_Rating', 'Num_Ratings']].head(10))
print("-" * 30)
# Out:
# ### Recommendations Based Popularity-Driven Average Rating ###
# Mean number of ratings per anime: 3416.32
# Median number of ratings per anime: 266.00
# Using a minimum rating threshold of: 200
#
# Top 10 Highest Rated Anime (with at least 200 ratings):
#                              anime_name  Avg_Rating  Num_Ratings
# 4456                           Gintama°    9.245648        20794
# 3891   Fullmetal Alchemist: Brotherhood    9.237010       134197
# 4378               Ginga Eiyuu Densetsu    9.224730         9438
# 13909                       Steins;Gate    9.184228       122772
# 5821             Hunter x Hunter (2011)    9.169439        79970
# 4441                           Gintama'    9.150585        27692
# 4437                            Gintama    9.110528        34326
# 2322               Clannad: After Story    9.053407        88658
# 4442                Gintama': Enchousen    9.043576        22352
# 99           3-gatsu no Lion 2nd Season    9.036179        21532
# ------------------------------

# %%
print("\n### Recommendations Based on Weighted Scoring ###")



max_num_ratings = anime_stats['Num_Ratings'].max()
max_avg_rating = anime_stats['Avg_Rating'].max()

if max_num_ratings == 0 or max_avg_rating == 0:
    print("Warning: Max number of ratings or max average rating is zero. Cannot calculate weighted score.")
else:
    # Normalize the number of ratings and average ratings
    anime_stats['Norm_Num_Ratings'] = anime_stats['Num_Ratings'] / max_num_ratings
    anime_stats['Norm_Avg_Rating'] = anime_stats['Avg_Rating'] / max_avg_rating # Using max observed avg rating

    # Define weights for popularity vs. rating
    W1 = 0.5  # Popularity weight
    W2 = 0.5  # Average rating weight
    print(f"Using Weights: Popularity (W1) = {W1}, Average Rating (W2) = {W2}")

    # Calculate the weighted score
    anime_stats['Weighted_Score'] = (W1 * anime_stats['Norm_Num_Ratings']) + (W2 * anime_stats['Norm_Avg_Rating'])

    # Sort by the weighted score
    weighted_ranked_anime = anime_stats.sort_values(by='Weighted_Score', ascending=False)

    print("\nTop 10 Anime based on Weighted Score:")
    print(weighted_ranked_anime[['anime_name', 'Avg_Rating', 'Num_Ratings', 'Weighted_Score']].head(10))
    print("-" * 30)
# Out:
# ### Recommendations Based on Weighted Scoring ###
# Using Weights: Popularity (W1) = 0.5, Average Rating (W2) = 0.5
#
# Top 10 Anime based on Weighted Score:
#                              anime_name  Avg_Rating  Num_Ratings  \
# 2784                         Death Note    8.706566       182375
# 13176                Shingeki no Kyojin    8.514506       169794
# 3891   Fullmetal Alchemist: Brotherhood    9.237010       134197
# 2370    Code Geass: Hangyaku no Lelouch    8.768004       137291
# 14141                  Sword Art Online    7.403593       161192
# 10871                     One Punch Man    8.575559       138924
# 604                        Angel Beats!    8.246756       141127
# 13909                       Steins;Gate    9.184228       122772
# 15060                         Toradora!    8.368186       135524
# 12818     Sen to Chihiro no Kamikakushi    8.768119       127531
#
#        Weighted_Score
# 2784         0.935328
# 13176        0.891233
# 3891         0.829765
# 2370         0.814798
# 14141        0.812104
# 10871        0.809653
# 604          0.799252
# 13909        0.795804
# 15060        0.789962
# 12818        0.788045
# ------------------------------

# %%
print("\n### Recommendations Based on Bayesian Scoring ###")



# Calculate global average rating (m)
global_avg_rating = rating_df_clean['rating'].mean()
print(f"Global average rating (m): {global_avg_rating:.4f}")

# Calculate the mean number of ratings across all anime (C - confidence factor)
# Using the previously calculated anime_stats['Num_Ratings']
C = anime_stats['Num_Ratings'].mean()
print(f"Mean number of ratings per anime (C): {C:.4f}")

# Apply the Bayesian Rating formula
# Bayesian Rating = (C * m + Num_Ratings * Avg_Rating) / (C + Num_Ratings)
anime_stats['Bayesian_Rating'] = (
    (C * global_avg_rating + anime_stats['Num_Ratings'] * anime_stats['Avg_Rating']) /
    (C + anime_stats['Num_Ratings'])
)

# Sort by the Bayesian rating
bayesian_ranked_anime = anime_stats.sort_values(by='Bayesian_Rating', ascending=False)

print("\nTop 10 Anime based on Bayesian Rating:")
print(bayesian_ranked_anime[['anime_name', 'Avg_Rating', 'Num_Ratings', 'Bayesian_Rating']].head(10))
print("-" * 30)

print("\nNon-personalized recommendation generation complete.")
# Out:
# ### Recommendations Based on Bayesian Scoring ###
# Global average rating (m): 7.5108
# Mean number of ratings per anime (C): 3416.3176
#
# Top 10 Anime based on Bayesian Rating:
#                                anime_name  Avg_Rating  Num_Ratings  \
# 3891     Fullmetal Alchemist: Brotherhood    9.237010       134197
# 13909                         Steins;Gate    9.184228       122772
# 5821               Hunter x Hunter (2011)    9.169439        79970
# 4456                             Gintama°    9.245648        20794
# 2322                 Clannad: After Story    9.053407        88658
# 4441                             Gintama'    9.150585        27692
# 4437                              Gintama    9.110528        34326
# 13184  Shingeki no Kyojin Season 3 Part 2    9.032606        67473
# 7647                       Koe no Katachi    8.945412        99930
# 2382   Code Geass: Hangyaku no Lelouch R2    8.929797       121604
#
#        Bayesian_Rating
# 3891          9.194155
# 13909         9.138922
# 5821          9.101484
# 4456          9.000842
# 2322          8.996170
# 4441          8.970502
# 4437          8.965725
# 13184         8.959266
# 7647          8.897987
# 2382          8.891021
# ------------------------------
#
# Non-personalized recommendation generation complete.
